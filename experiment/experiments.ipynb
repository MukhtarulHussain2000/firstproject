# %% [markdown]
# <H1>Exploratory Data Analysis

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:/Projects/MLOps/gitClones/firstproject/datasets/Diamonds Prices2022.csv")

# %%
data.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48
# 6  3.98  2.47
# 7  4.11  2.53
# 8  3.78  2.49
# ...

# %%
data_origin = data.copy()

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
Unnamed_cols = data.loc[:, data.columns.str.contains('^Unnamed')]
data.drop(Unnamed_cols, axis=1, inplace=True)

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium     F     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
# Checking and removing duplicated Rows

# Checking
data.duplicated().sum()

# Validating if the rows are truly duplicated and can be removed
dup = data[data.duplicated(keep='first')] # by default keep='first', no explicit mention is required

print(dup)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1005    0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1006    0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1007    0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1008    0.79      Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 2025    1.52       Good     E      I1   57.3   58.0   3105  7.53  7.42  4.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 50079   0.51      Ideal     F    VVS2   61.2   56.0   2203  5.19  5.17  3.17
# 52861   0.50       Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [149 rows x 10 columns]

# %%
# After a careful observation of the duplicated columns it was found that the duplicated occurences can be dropped.

# Removing Rows
print("No. of rows before removing duplicates: ", len(data_origin))

data.drop_duplicates(inplace=True)

print("No. of rows before removing duplicates: ", len(data))

print("No. of rows deleted: ", len(data_origin)-len(data))
# Out:
# No. of rows before removing duplicates:  53943
# No. of rows before removing duplicates:  53794
# No. of rows deleted:  149

# %%
data.shape
# Out:
# (53794, 10)

# %%
sample = data.sample(10)

# %%
sample
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 31222   0.32  Very Good     D     SI1   63.2   54.0    756  4.38  4.36  2.76
# 21877   1.50       Good     H     SI1   64.3   60.0   9946  7.23  7.14  4.62
# 53252   0.72    Premium     G     VS1   62.3   61.0   2646  5.73  5.66  3.55
# 28162   0.30      Ideal     H    VVS1   61.6   57.0    665  4.30  4.34  2.66
# 53820   0.71    Premium     G     VS2   63.0   56.0   2735  5.70  5.69  3.59
# 19271   1.21    Premium     G     VS2   62.2   58.0   7996  6.85  6.81  4.25
# 22246   1.50       Good     D     SI2   61.9   61.0  10302  7.31  7.38  4.55
# 206     0.70  Very Good     E     SI1   63.2   60.0   2777  5.60  5.51  3.51
# 3936    0.93       Good     H     VS1   59.1   64.0   3500  6.36  6.27  3.73
# 28057   0.38      Ideal     F     SI1   62.2   54.0    660  4.64  4.66  2.89

# %%
sample.describe()
# Out:
#            carat      depth     table         price          x          y  \
# count  10.000000  10.000000  10.00000     10.000000  10.000000  10.000000
# mean    0.827000  62.300000  58.50000   4198.300000   5.810000   5.782000
# std     0.452034   1.375177   3.27448   3780.439982   1.125808   1.113072
# min     0.300000  59.100000  54.00000    660.000000   4.300000   4.340000
# 25%     0.460000  61.975000  56.25000   1228.500000   4.880000   4.872500
# 50%     0.715000  62.250000  59.00000   2756.000000   5.715000   5.675000
# 75%     1.140000  63.150000  60.75000   6872.000000   6.727500   6.675000
# max     1.500000  64.300000  64.00000  10302.000000   7.310000   7.380000
#
#                z
# count  10.000000
# mean    3.611000
# std     0.705934
# min     2.660000
# 25%     3.045000
# 50%     3.570000
# 75%     4.120000
# max     4.620000

# %%
sample['color'].value_counts(normalize=False, sort=True, ascending=True, dropna= True)
# Out:
# color
# E    1
# F    1
# D    2
# H    3
# G    3
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  object
#  2   color    53794 non-null  object
#  3   clarity  53794 non-null  object
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  int64
#  7   x        53794 non-null  float64
#  8   y        53794 non-null  float64
#  9   z        53794 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %%
# segregating the data based on categorical and numeric columns
cat_data = data.columns[data.dtypes=="object"]
num_data = data.columns[data.dtypes!="object"]

# %%
data[cat_data]
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53794 rows x 3 columns]

# %%
data[num_data]
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53794 rows x 7 columns]

# %%
data[num_data].describe()
# Out:
#              carat         depth         table         price             x  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109   3933.065082      5.731214
# std        0.47339      1.429909      2.233679   3988.114460      1.120695
# min        0.20000     43.000000     43.000000    326.000000      0.000000
# 25%        0.40000     61.000000     56.000000    951.000000      4.710000
# 50%        0.70000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.04000     62.500000     59.000000   5326.750000      6.540000
# max        5.01000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53794.000000  53794.000000
# mean       5.734653      3.538714
# std        1.141209      0.705037
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.030000
# ...

# %%
data[cat_data].describe()
# Out:
#           cut  color clarity
# count   53794  53794   53794
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21488  11262   13032

# %%
data['cut'].value_counts()
# Out:
# cut
# Ideal        21488
# Premium      13748
# Very Good    12069
# Good          4891
# Fair          1598
# Name: count, dtype: int64

# %%
data['color'].value_counts()
# Out:
# color
# G    11262
# E     9776
# F     9520
# H     8272
# D     6755
# I     5407
# J     2802
# Name: count, dtype: int64

# %%
data['clarity'].value_counts()
# Out:
# clarity
# SI1     13032
# VS2     12229
# SI2      9150
# VS1      8156
# VVS2     5056
# VVS1     3647
# IF       1784
# I1        740
# Name: count, dtype: int64

# %%
cut_map = {
     "Ideal": 1,
     "Premium": 2,
     "Very Good": 3,
     "Good": 4,
     "Fair": 5,
}

color_map = {
     "D": 1,
     "E": 2,
     "F": 3,
     "G": 4,
     "H": 5,
     "I": 6,
     "J": 7,
}

clarity_map = {
     "VVS1": 2,
     "VVS2": 3,
     "VS1": 4,
     "VS2": 5,
     "SI1": 6,
     "SI2": 7,
     "I1": 8,
}

# %%
# Ordinal Encoding for categorical columns

data['cut'] = data['cut'].map(cut_map)
data['color'] = data['color'].map(color_map)
data['clarity'] = data['clarity'].map(clarity_map)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))

for cols in num_data:
     sns.histplot(data=data, x=cols, kde=True)
     print("\n")
     plt.show()

# %%
sns.heatmap(data[num_data].corr(), annot=True)
# Out:
# <Axes: >
